# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiran210605/Tech-a-intern/blob/main/Stock_Market_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
bitcoin=yf.Ticker("BTC-USD")
bitcoin=bitcoin.history(period='max')
bitcoin
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-11-01 00:00:00+00:00  34657.273438  35527.929688  34170.691406
# 2023-11-02 00:00:00+00:00  35441.578125  35919.843750  34401.574219
# 2023-11-03 00:00:00+00:00  34942.472656  34942.472656  34133.441406
# 2023-11-04 00:00:00+00:00  34736.324219  35256.031250  34616.691406
# 2023-11-06 00:00:00+00:00  35044.789062  35286.027344  34772.433594
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2014-09-17 00:00:00+00:00', '2014-09-18 00:00:00+00:00',
#                '2014-09-19 00:00:00+00:00', '2014-09-20 00:00:00+00:00',
#                '2014-09-21 00:00:00+00:00', '2014-09-22 00:00:00+00:00',
#                '2014-09-23 00:00:00+00:00', '2014-09-24 00:00:00+00:00',
#                '2014-09-25 00:00:00+00:00', '2014-09-26 00:00:00+00:00',
#                ...
#                '2023-10-27 00:00:00+00:00', '2023-10-28 00:00:00+00:00',
#                '2023-10-29 00:00:00+00:00', '2023-10-30 00:00:00+00:00',
#                '2023-10-31 00:00:00+00:00', '2023-11-01 00:00:00+00:00',
#                '2023-11-02 00:00:00+00:00', '2023-11-03 00:00:00+00:00',
#                '2023-11-04 00:00:00+00:00', '2023-11-06 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=3337, freq=None)

# %% [markdown]
# Preprocessiong and Data Visualization

# %%
bitcoin.plot.line(y='Close',use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin['Tmr']=bitcoin['Close'].shift(-1)

# %%
bitcoin
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-11-01 00:00:00+00:00  34657.273438  35527.929688  34170.691406
# 2023-11-02 00:00:00+00:00  35441.578125  35919.843750  34401.574219
# 2023-11-03 00:00:00+00:00  34942.472656  34942.472656  34133.441406
# 2023-11-04 00:00:00+00:00  34736.324219  35256.031250  34616.691406
# 2023-11-06 00:00:00+00:00  35044.789062  35286.027344  34772.433594
#
#                                   Close       Volume  Dividends  Stock Splits  \
# Date
# ...

# %%
bitcoin['Target']=(bitcoin['Tmr']>bitcoin['Close']).astype(int)

# %%
bitcoin
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2023-11-01 00:00:00+00:00  34657.273438  35527.929688  34170.691406
# 2023-11-02 00:00:00+00:00  35441.578125  35919.843750  34401.574219
# 2023-11-03 00:00:00+00:00  34942.472656  34942.472656  34133.441406
# 2023-11-04 00:00:00+00:00  34736.324219  35256.031250  34616.691406
# 2023-11-06 00:00:00+00:00  35044.789062  35286.027344  34772.433594
#
#                                   Close       Volume  Dividends  Stock Splits  \
# Date
# ...

# %% [markdown]
# Training an Initial Model

# %%
#im using radnomforestclassifier because it works on bunch of individual decision tress with randomized parameters
#its hard to overfit & also runs Quickly
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=1)
train=bitcoin.iloc[:-100]
test=bitcoin.iloc[-100:]
predictors=["Close","Volume","Open","High","Low"]
model.fit(train[predictors],train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
preds=model.predict(test[predictors])

# %%
import pandas as pd
preds=pd.Series(preds,index=test.index)
preds
# Out:
# Date
# 2023-07-29 00:00:00+00:00    1
# 2023-07-30 00:00:00+00:00    1
# 2023-07-31 00:00:00+00:00    1
# 2023-08-01 00:00:00+00:00    1
# 2023-08-02 00:00:00+00:00    1
#                             ..
# 2023-11-01 00:00:00+00:00    0
# 2023-11-02 00:00:00+00:00    0
# 2023-11-03 00:00:00+00:00    0
# 2023-11-04 00:00:00+00:00    1
# 2023-11-06 00:00:00+00:00    0
# Length: 100, dtype: int64

# %%
precision_score(test['Target'],preds)
# Out:
# 0.4861111111111111

# %% [markdown]
# the above precision is not that good -- we need more good precision_score

# %%
combined=pd.concat([test['Target'],preds],axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Orange is 0 And Blue is 1

# %% [markdown]
# Building a Backtesting System

# %%
#Defineing a Fun
def predict(train,test,predictors,mode):
  model.fit(train[predictors],train['Target'])
  preds=model.predict(test[predictors])
  preds=pd.Series(preds,index=test.index,name="Predictions")
  combined=pd.concat([test['Target'],preds],axis=1)
  return combined

# %%
def backtest(data,model,predictors,start=2500,step=250):
  #here start is 10 years of data, ie we train 1st model with 10yrs of data then predict values for the 11th year and so on
  all_predictions=[]
  for i in range(start,data.shape[0],step):
    train=data.iloc[0:i].copy()
    test=data.iloc[i:(i+step)].copy()
    predictions=predict(train,test,predictors,model)
    all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions=backtest(bitcoin,model,predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# 0    244
# 1      6
# Name: Predictions, dtype: int64

# %%
precision_score(predictions['Target'],predictions['Predictions'])
# Out:
# 0.6666666666666666

# %% [markdown]
# The 66.6% the model is Good -- but lets do some more to make this model even precise

# %%
predictions['Target'].value_counts() / predictions.shape[0]
# Out:
# 1    0.524
# 0    0.476
# Name: Target, dtype: float64

# %% [markdown]
# Says that 52.4 % the prediction will go UP and 47.6% the predictions will go DOWN
